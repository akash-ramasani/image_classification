# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.4.0

# %% [raw]
# torchvision is a companion library to PyTorch designed specifically for Computer Vision.
#
# 4 Pillars of torchvision
#
# torchvision.datasets is a module inside the torchvision library that provides ready to use datasets for computer vision tasks.

# %%
import torchvision.datasets as dsets

# %%
print(dsets)
# Out:
# <module 'torchvision.datasets' from '/Users/rc/Desktop/Akash/Projects/Classification/image_classification/venv/lib/python3.13/site-packages/torchvision/datasets/__init__.py'>

# %%
all_datasets = [name for name in dir(dsets) if not name.startswith("_") and name[0].isupper()]

# %%
for d in all_datasets:
    print(d)
# Out:
# CIFAR10
# CIFAR100
# CLEVRClassification
# CREStereo
# Caltech101
# Caltech256
# CarlaStereo
# CelebA
# Cityscapes
# CocoCaptions
# CocoDetection
# Country211
# DTD
# DatasetFolder
# EMNIST
# ETH3DStereo
# EuroSAT
# FER2013
# FGVCAircraft
# FakeData
# FallingThingsStereo
# FashionMNIST
# Flickr30k
# Flickr8k
# Flowers102
# FlyingChairs
# FlyingThings3D
# Food101
# GTSRB
# HD1K
# HMDB51
# INaturalist
# ImageFolder
# ImageNet
# Imagenette
# InStereo2k
# KMNIST
# Kinetics
# Kitti
# Kitti2012Stereo
# Kitti2015Stereo
# KittiFlow
# LFWPairs
# LFWPeople
# LSUN
# LSUNClass
# MNIST
# Middlebury2014Stereo
# MovingMNIST
# Omniglot
# OxfordIIITPet
# PCAM
# PhotoTour
# Places365
# QMNIST
# RenderedSST2
# SBDataset
# SBU
# SEMEION
# STL10
# SUN397
# SVHN
# SceneFlowStereo
# Sintel
# SintelStereo
# StanfordCars
# UCF101
# USPS
# VOCDetection
# VOCSegmentation
# VisionDataset
# WIDERFace
