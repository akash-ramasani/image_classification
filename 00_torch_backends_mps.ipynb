# %%
import torch

# %%
print(torch.cuda)
# Out:
# <module 'torch.cuda' from '/Users/rc/Desktop/Akash/Projects/Classification/image_classification/venv/lib/python3.13/site-packages/torch/cuda/__init__.py'>

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
print(torch.cuda.device_count())
# Out:
# 0

# %%
print(torch.backends.mps)
# Out:
# <module 'torch.backends.mps' from '/Users/rc/Desktop/Akash/Projects/Classification/image_classification/venv/lib/python3.13/site-packages/torch/backends/mps/__init__.py'>

# %%
print(torch.backends.mps.is_available())
# Out:
# True

# %%
print(torch.backends.mps.is_built())
# Out:
# True

# %%
print(torch.backends.mps.is_macos13_or_newer())
# Out:
# True

# %%
print(torch.mps.device_count())
# Out:
# 1

# %%
print(torch.mps.current_allocated_memory())
# Out:
# 0

# %%
print(torch.mps.driver_allocated_memory()/ 1e9)
# Out:
# 0.000475136

# %%
print(torch.mps.recommended_max_memory()/ 1e9)
# Out:
# 5.726633984
