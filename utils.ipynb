# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.9.1

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
print(torch.cuda)
# Out:
# <module 'torch.cuda' from '/Users/rc/Desktop/Akash/Projects/Classification/image_classification/venv/lib/python3.13/site-packages/torch/cuda/__init__.py'>

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
import torchvision

# %%
print(torchvision.__version__)
# Out:
# 0.24.1

# %%
import torch, torchvision; print('torch', torch.__version__); print('torchvision', torchvision.__version__); print('cuda?', torch.cuda.is_available())
# Out:
# torch 2.9.1
# torchvision 0.24.1
# cuda? False

# %%
import torch; x=torch.randn(2,3,32,32); print(x.shape, x.dtype, x.device)
# Out:
# torch.Size([2, 3, 32, 32]) torch.float32 cpu
